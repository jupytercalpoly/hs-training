# %%
import pandas as pd

# %%
cases = pd.read_csv('us_confirmed.csv', index_col=0)

# %%
cases.head(10)
# Out:
#         UID iso2 iso3  code3    FIPS   Admin2            Province_State  \
# 0        16   AS  ASM     16    60.0      NaN            American Samoa
# 1       316   GU  GUM    316    66.0      NaN                      Guam
# 2       580   MP  MNP    580    69.0      NaN  Northern Mariana Islands
# 3       630   PR  PRI    630    72.0      NaN               Puerto Rico
# 4       850   VI  VIR    850    78.0      NaN            Virgin Islands
# 5  84001001   US  USA    840  1001.0  Autauga                   Alabama
# 6  84001003   US  USA    840  1003.0  Baldwin                   Alabama
# 7  84001005   US  USA    840  1005.0  Barbour                   Alabama
# 8  84001007   US  USA    840  1007.0     Bibb                   Alabama
# 9  84001009   US  USA    840  1009.0   Blount                   Alabama
#
#   Country_Region        Lat       Long_  ... 5/30/20  5/31/20  6/1/20  6/2/20  \
# 0             US -14.271000 -170.132000  ...       0        0       0       0
# ...

# %%
subset = cases.copy().iloc[5:,]

# %%
subset = subset[['UID','Admin2','Province_State','6/1/20']].rename(columns={'6/1/20':'cases'})

# %%
deaths = pd.read_csv('us_deaths.csv', index_col=0)

# %%
subset_d = deaths.copy().iloc[5:,]

# %%
subset_d = subset_d[['UID','6/1/20']].rename(columns={'6/1/20':'deaths'})

# %%
df = subset.merge(subset_d, on='UID')

# %%
df.head()
# Out:
#         UID   Admin2 Province_State  cases  deaths
# 0  84001001  Autauga        Alabama    233       5
# 1  84001003  Baldwin        Alabama    292       9
# 2  84001005  Barbour        Alabama    172       1
# 3  84001007     Bibb        Alabama     76       1
# 4  84001009   Blount        Alabama     63       1

# %%
df["FIPS"] = df['UID'].astype(str).str[-5:].astype(str)

# %%
df["FIPS"]
# Out:
# 0       01001
# 1       01003
# 2       01005
# 3       01007
# 4       01009
#         ...
# 3251    70016
# 3252    70017
# 3253    70018
# 3254    70019
# 3255    70020
# Name: FIPS, Length: 3256, dtype: object

# %%
df.to_csv('counties_june1.csv')
