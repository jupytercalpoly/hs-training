# %%
import requests
import json
import pandas as pd
from pathlib import Path

# %%
# read in with pandas
df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/' +
            'csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv')

# %%
df.to_csv('us_confirmed.csv')

# %%
# fill in with github personal access token
token = 'token xxx'

# %%
# get one file with requests - blob
files = requests.get('https://api.github.com/repos/CSSEGISandData/COVID-19/' +
                     'contents/csse_covid_19_data/csse_covid_19_time_series/').json()
sha = ''
for f in files:
    if f.get('name') == 'time_series_covid19_confirmed_US.csv':
        sha = f.get('sha')
data = requests.get('https://api.github.com/repos/CSSEGISandData/COVID-19/'+
                 'git/blobs/' + sha, headers={'Authorization': token})
blob = data.json().get('content')

# %%
# get all (small) files with requests programmatically
files = requests.get('https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports_us',
                     headers={'Authorization': token}).json()
for f in files:
    data = requests.get('https://api.github.com/repos/CSSEGISandData/COVID-19/contents/' + f.get('path'), 
                        headers={'Authorization': token}).json()
    realdata = requests.get(data.get('download_url'))
    file = open("data/" + data.get('name'),'w') 
    file.write(realdata.text) 
    file.close()

# %%
for f in files:
    data = requests.get('https://api.github.com/repos/CSSEGISandData/COVID-19/contents/' + f.get('path'), 
                        headers={'Authorization': 'token 34aec0b00a206c0415000623eecf796a474a4b68'}).json()
    realdata = requests.get(data.get('download_url'))
    file = open("data/" + data.get('name'),'w') 
    file.write(realdata.text) 
    file.close()

# %%
df2 = pd.DataFrame()
pathlist = Path('.').glob('data/*.csv')
for path in pathlist:
    df2 = df2.append(pd.read_csv(str(path)))

# %%
df2['Date']= pd.to_datetime(df2['Last_Update']).dt.date

# %%
df2.to_csv('us_daily.csv')

# %%
# explore data
list(df.columns)
# Out:
# ['UID',
#  'iso2',
#  'iso3',
#  'code3',
#  'FIPS',
#  'Admin2',
#  'Province_State',
#  'Country_Region',
#  'Lat',
#  'Long_',
#  'Combined_Key',
#  '1/22/20',
#  '1/23/20',
#  '1/24/20',
#  '1/25/20',
#  '1/26/20',
#  '1/27/20',
#  '1/28/20',
#  '1/29/20',
#  '1/30/20',
#  '1/31/20',
#  '2/1/20',
#  '2/2/20',
#  '2/3/20',
#  '2/4/20',
#  '2/5/20',
#  '2/6/20',
#  '2/7/20',
#  '2/8/20',
#  '2/9/20',
#  '2/10/20',
#  '2/11/20',
#  '2/12/20',
#  '2/13/20',
#  '2/14/20',
#  '2/15/20',
#  '2/16/20',
#  '2/17/20',
#  '2/18/20',
#  '2/19/20',
#  '2/20/20',
#  '2/21/20',
#  '2/22/20',
#  '2/23/20',
#  '2/24/20',
#  '2/25/20',
#  '2/26/20',
#  '2/27/20',
#  '2/28/20',
#  '2/29/20',
#  '3/1/20',
#  '3/2/20',
#  '3/3/20',
#  '3/4/20',
#  '3/5/20',
#  '3/6/20',
#  '3/7/20',
#  '3/8/20',
#  '3/9/20',
#  '3/10/20',
#  '3/11/20',
#  '3/12/20',
#  '3/13/20',
#  '3/14/20',
#  '3/15/20',
#  '3/16/20',
#  '3/17/20',
#  '3/18/20',
#  '3/19/20',
#  '3/20/20',
#  '3/21/20',
#  '3/22/20',
# ...

# %%
df.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_  ... 5/30/20  5/31/20  6/1/20  6/2/20  6/3/20  6/4/20  \
# 0 -14.2710 -170.1320  ...       0        0       0       0       0       0
# 1  13.4443  144.7937  ...     172      172     175     175     177     179
# 2  15.0979  145.6739  ...      22       22      22      23      24      26
# 3  18.2208  -66.5901  ...    3718     3776    3873    3935    4023    4508
# 4  18.3358  -64.8963  ...      69       69      70      70      70      71
#
#    6/5/20  6/6/20  6/7/20  6/8/20
# ...

# %%
df.describe()
# Out:
#                 UID        code3          FIPS          Lat        Long_  \
# count  3.261000e+03  3261.000000   3251.000000  3261.000000  3261.000000
# mean   8.390341e+07   839.445569  32090.929560    37.165903   -89.160375
# std    3.288463e+06    18.068968  17825.153176     8.662455    21.547038
# min    1.600000e+01    16.000000     60.000000   -14.271000  -170.132000
# 25%    8.401904e+07   840.000000  19038.000000    34.237321   -98.066628
# 50%    8.403006e+07   840.000000  30045.000000    38.149014   -89.827411
# 75%    8.404702e+07   840.000000  47010.000000    41.683301   -82.793570
# max    8.410000e+07   850.000000  99999.000000    69.314792   145.673900
#
#            1/22/20      1/23/20      1/24/20      1/25/20      1/26/20  ...  \
# count  3261.000000  3261.000000  3261.000000  3261.000000  3261.000000  ...
# mean      0.000307     0.000307     0.000613     0.000613     0.001533  ...
# std       0.017512     0.017512     0.024761     0.024761     0.039133  ...
# ...
